# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
my_Tuple1 = (2,3)
my_Tuple2 = (3,6)


tong = my_Tuple1[0] + my_Tuple2[0],my_Tuple1[1] + my_Tuple2[1]
nhan = my_Tuple1[0] * my_Tuple2[0],my_Tuple1[1] * my_Tuple2[1]
print("tong hai tuple",tong)
print("nhan hai tuple", nhan)
# Out:
# tong hai tuple (5, 9)
# nhan hai tuple (6, 18)
