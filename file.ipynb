# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list =[]
for i in range(1,10):
    list.append(i)
print(list,end=" - ")
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9] -

# %%
f = open("data.txt","w")
f.write(str(list))
f.close()
